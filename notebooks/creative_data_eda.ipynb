# %% [markdown]
# ## Creative Data Exploratory Data Analysis

# %% [markdown]
# ### Import Packages

# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../scripts')))
from utils import plot_pie_chart

# %%
creative_df = pd.read_csv("../data/creative_data.csv")
creative_df
# Out:
#     campaign_id                                           game_key adformat  \
# 0       8spf486  99c977cfa9e59bc96509f6ccf2945a5c/06691fc50d263...  320x480
# 1       sigze66  adunit-mouser-user-choice-flight6-uk-cpe-av-mo...  320x480
# 2       3v47f4o  cdef57366ecbfd7a26ae7f17144c9a1d/b3163069df6ba...  300x250
# 3       ok34g8y  a08b73657c07c7ce9031088312ee7461/de60be3caf0d1...  320x480
# 4       jkzt1vs  98ff4975d916f865fccaf63b35059835/8e1613b604a91...  300x250
# ..          ...                                                ...      ...
# 224     281yw38  adunit-nandos-winter-hotpot-&-soup-tap-user-ch...  320x480
# 225     noaiquo  adunit-sanlam-life-of-confidence-tap-user-choi...  320x480
# 226     vwulda0  adunit-himalaya-personal-care-septilin-and-kof...  320x480
# 227     iovkeuo  adunit-hunters-big-summer-cycle-slider-fullscr...  320x480
# 228     fisff0r  5035032902fc424b9b134cdf24886abe/6b6d4f8c0e96c...  320x480
#
#                creative
# 0    Sensory Engagement
# ...

# %%
creative_df.columns
# Out:
# Index(['campaign_id', 'game_key', 'adformat', 'creative'], dtype='object')

# %%
campaign_id_counts = creative_df['campaign_id'].value_counts()
print(campaign_id_counts)
# Out:
# campaign_id
# s9tv2we    22
# sigze66    11
# a5mcfox    11
# noaiquo     8
# 66bpf2h     4
#            ..
# scc0f0s     1
# lv45xzm     1
# erkvo1a     1
# 281yw38     1
# iovkeuo     1
# Name: count, Length: 79, dtype: int64

# %% [markdown]
# #### adformat Analysis

# %%
plot_pie_chart(creative_df['adformat'], "Ad Format")

# %% [markdown]
# - The 'adformat' column contains various dimensions of ad formats, with the majority <br/> being 320x480, followed by 300x250 and 320x50.

# %% [markdown]
# #### Creative Category Analysis

# %%
plot_pie_chart(creative_df['creative'], "Creative Category")

# %% [markdown]
# <div style="border-left: 2px solid silver; padding-left: 10px;">
#
# The analysis of creative types reveals "Sensory Engagement" as the most common, followed by "Sensory Video," "Sensory Plus," <br/>
#  and "User Choice." "Gamification" is less frequent. This suggests a diverse approach to ad creatives, with a notable emphasis on<br>
#  sensory engagement and video content.
#
# </div>
